# %% [markdown]
# # Logstic Regression

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from warnings import filterwarnings
filterwarnings("ignore")

# %% [markdown]
# ## Step 1 - Read the dataset

# %%
import pandas as pd
df = pd.read_csv("iris.csv")
df.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %% [markdown]
# ## Step 2 - Perform basic data quality checks

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
df.isna().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(1)

# %% [markdown]
# ## Step 3 - Seperate X and Y

# %%
X = df.drop(columns=["species"])
Y = df[["species"]]

# %%
X.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0           5.1          3.5           1.4          0.2
# 1           4.9          3.0           1.4          0.2
# 2           4.7          3.2           1.3          0.2
# 3           4.6          3.1           1.5          0.2
# 4           5.0          3.6           1.4          0.2

# %%
Y.head()
# Out:
#   species
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
Y.value_counts()
# Out:
# species
# setosa        50
# versicolor    50
# virginica     50
# Name: count, dtype: int64

# %%
X.dtypes
# Out:
# sepal_length    float64
# sepal_width     float64
# petal_length    float64
# petal_width     float64
# dtype: object

# %% [markdown]
# ## Step 4 - Create a preprocessing pipeline on X

# %%
from sklearn.pipeline import make_pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler

# %%
num_pipe = make_pipeline(
    SimpleImputer(strategy="mean"),
    StandardScaler()
).set_output(transform="pandas")

# %%
X_pre = num_pipe.fit_transform(X)
X_pre.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width
# 0     -0.900681     1.019004     -1.340227    -1.315444
# 1     -1.143017    -0.131979     -1.340227    -1.315444
# 2     -1.385353     0.328414     -1.397064    -1.315444
# 3     -1.506521     0.098217     -1.283389    -1.315444
# 4     -1.021849     1.249201     -1.340227    -1.315444

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %% [markdown]
# ## Step 5 - Train Test Split
# test - 0.33

# %%
from sklearn.model_selection import train_test_split

xtrain, xtest, ytrain, ytest = train_test_split(
    X_pre, Y, test_size=0.33, random_state=21
)

# %%
xtrain.head()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width
# 52       1.280340     0.098217      0.649083     0.395774
# 49      -1.021849     0.558611     -1.340227    -1.315444
# 65       1.038005     0.098217      0.364896     0.264142
# 118      2.249683    -1.052767      1.785832     1.448832
# 55      -0.173674    -0.592373      0.421734     0.132510

# %%
ytrain.head()
# Out:
#         species
# 52   versicolor
# 49       setosa
# 65   versicolor
# 118   virginica
# 55   versicolor

# %%
xtest.head()
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 92     -0.052506    -1.052767      0.137547     0.000878
# 44     -0.900681     1.709595     -1.056039    -1.052180
# 7      -1.021849     0.788808     -1.283389    -1.315444
# 21     -0.900681     1.479398     -1.283389    -1.052180
# 95     -0.173674    -0.131979      0.251221     0.000878

# %%
ytest.head()
# Out:
#        species
# 92  versicolor
# 44      setosa
# 7       setosa
# 21      setosa
# 95  versicolor

# %%
xtrain.shape
# Out:
# (100, 4)

# %%
xtest.shape
# Out:
# (50, 4)

# %% [markdown]
# ## Step 6 - Model Building

# %%
from sklearn.linear_model import LogisticRegression

# %%
model = LogisticRegression()
model.fit(xtrain, ytrain)
# Out:
# c:\ML\repository\venv\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %% [markdown]
# ## Step 7 - Model evaluation

# %%
model.score(xtrain, ytrain)
# Out:
# 0.98

# %%
model.score(xtest, ytest)
# Out:
# 0.94

# %%
ypred_train = model.predict(xtrain)
ypred_test = model.predict(xtest)

# %%
ypred_train[0:5]
# Out:
# array(['versicolor', 'setosa', 'versicolor', 'virginica', 'versicolor'],
#       dtype=object)

# %%
ytrain.head()
# Out:
#         species
# 52   versicolor
# 49       setosa
# 65   versicolor
# 118   virginica
# 55   versicolor

# %%
ypred_test[0:5]
# Out:
# array(['versicolor', 'setosa', 'setosa', 'setosa', 'versicolor'],
#       dtype=object)

# %%
ytest.head()
# Out:
#        species
# 92  versicolor
# 44      setosa
# 7       setosa
# 21      setosa
# 95  versicolor

# %%
from sklearn.metrics import ConfusionMatrixDisplay
ConfusionMatrixDisplay.from_estimator(model, xtest, ytest)

# %%
from sklearn.metrics import classification_report
print(classification_report(ytest, ypred_test))
# Out:
#               precision    recall  f1-score   support
#
#       setosa       1.00      1.00      1.00        18
#   versicolor       1.00      0.82      0.90        17
#    virginica       0.83      1.00      0.91        15
#
#     accuracy                           0.94        50
#    macro avg       0.94      0.94      0.94        50
# weighted avg       0.95      0.94      0.94        50

# %% [markdown]
# ## From above data the f1 macro avg on test data is 0.94 > 0.8 hence it is considered as a good model

# %% [markdown]
# ## Step 8 - Out of sample prediction

# %%
xnew = pd.read_csv("iris_sample.csv")
xnew
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0            5.5          2.5           4.0          1.3
# 1            6.9          3.1           5.1          2.3
# 2            5.1          2.5           3.0          1.1
# 3            4.4          2.9           NaN          0.2
# 4            5.9          3.0           5.1          1.8
# 5            5.5          3.5           1.3          0.2
# 6            5.6          NaN           3.6          1.3
# 7            6.5          3.0           5.2          2.0
# 8            5.3          3.7           1.5          0.2
# 9            5.1          3.4           1.5          NaN
# 10           6.1          2.8           4.0          1.3
# 11           5.5          2.4           3.7          1.0
# 12           7.7          3.0           6.1          2.3
# 13           6.9          3.1           4.9          1.5
# 14           6.0          2.2           5.0          1.5

# %%
num_pipe
# Out:
# Pipeline(steps=[('simpleimputer', SimpleImputer()),
#                 ('standardscaler', StandardScaler())])

# %%
xnew_pre = num_pipe.transform(xnew)
xnew_pre
# Out:
#     sepal_length  sepal_width  petal_length  petal_width
# 0      -0.416010    -1.282963      0.137547     0.132510
# 1       1.280340     0.098217      0.762758     1.448832
# 2      -0.900681    -1.282963     -0.430828    -0.130755
# 3      -1.748856    -0.362176      0.000000    -1.315444
# 4       0.068662    -0.131979      0.762758     0.790671
# 5      -0.416010     1.019004     -1.397064    -1.315444
# 6      -0.294842     0.000000     -0.089803     0.132510
# 7       0.795669    -0.131979      0.819596     1.053935
# 8      -0.658345     1.479398     -1.283389    -1.315444
# 9      -0.900681     0.788808     -1.283389     0.000000
# 10      0.310998    -0.592373      0.137547     0.132510
# 11     -0.416010    -1.513160     -0.032966    -0.262387
# 12      2.249683    -0.131979      1.331133     1.448832
# 13      1.280340     0.098217      0.649083     0.395774
# 14      0.189830    -1.973554      0.705921     0.395774

# %%
ypred = model.predict(xnew_pre)
ypred
# Out:
# array(['versicolor', 'virginica', 'versicolor', 'setosa', 'virginica',
#        'setosa', 'versicolor', 'virginica', 'setosa', 'setosa',
#        'versicolor', 'versicolor', 'virginica', 'versicolor', 'virginica'],
#       dtype=object)

# %%
yprob = model.predict_proba(xnew_pre)
yprob
# Out:
# array([[1.93292727e-02, 8.82537594e-01, 9.81331333e-02],
#        [1.80315390e-04, 6.76221053e-02, 9.32197579e-01],
#        [9.73213051e-02, 8.91868487e-01, 1.08102083e-02],
#        [7.45709340e-01, 2.54116291e-01, 1.74368528e-04],
#        [5.90541932e-03, 3.31763397e-01, 6.62331183e-01],
#        [9.63296887e-01, 3.67026084e-02, 5.04715947e-07],
#        [1.60683756e-01, 8.11677570e-01, 2.76386741e-02],
#        [7.55605408e-04, 1.55677416e-01, 8.43566978e-01],
#        [9.85175448e-01, 1.48243463e-02, 2.05612795e-07],
#        [8.87027458e-01, 1.12886703e-01, 8.58384446e-05],
#        [2.30367528e-02, 8.97506058e-01, 7.94571891e-02],
#        [2.62907569e-02, 9.48058330e-01, 2.56509126e-02],
#        [3.40647499e-06, 1.34534099e-02, 9.86543184e-01],
#        [5.75880409e-03, 6.45418038e-01, 3.48823158e-01],
#        [4.93349887e-04, 4.04352561e-01, 5.95154090e-01]])

# %%
model.classes_
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
xnew["species_pred"] = ypred
xnew[model.classes_] = yprob

# %%
xnew
# Out:
#     sepal_length  sepal_width  petal_length  petal_width species_pred  \
# 0            5.5          2.5           4.0          1.3   versicolor
# 1            6.9          3.1           5.1          2.3    virginica
# 2            5.1          2.5           3.0          1.1   versicolor
# 3            4.4          2.9           NaN          0.2       setosa
# 4            5.9          3.0           5.1          1.8    virginica
# 5            5.5          3.5           1.3          0.2       setosa
# 6            5.6          NaN           3.6          1.3   versicolor
# 7            6.5          3.0           5.2          2.0    virginica
# 8            5.3          3.7           1.5          0.2       setosa
# 9            5.1          3.4           1.5          NaN       setosa
# 10           6.1          2.8           4.0          1.3   versicolor
# 11           5.5          2.4           3.7          1.0   versicolor
# 12           7.7          3.0           6.1          2.3    virginica
# 13           6.9          3.1           4.9          1.5   versicolor
# 14           6.0          2.2           5.0          1.5    virginica
#
#       setosa  versicolor     virginica
# 0   0.019329    0.882538  9.813313e-02
# 1   0.000180    0.067622  9.321976e-01
# 2   0.097321    0.891868  1.081021e-02
# 3   0.745709    0.254116  1.743685e-04
# 4   0.005905    0.331763  6.623312e-01
# 5   0.963297    0.036703  5.047159e-07
# 6   0.160684    0.811678  2.763867e-02
# 7   0.000756    0.155677  8.435670e-01
# 8   0.985175    0.014824  2.056128e-07
# 9   0.887027    0.112887  8.583844e-05
# 10  0.023037    0.897506  7.945719e-02
# 11  0.026291    0.948058  2.565091e-02
# 12  0.000003    0.013453  9.865432e-01
# 13  0.005759    0.645418  3.488232e-01
# 14  0.000493    0.404353  5.951541e-01

# %%
xnew.to_csv("Results.csv", index=False)
